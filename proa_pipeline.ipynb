# %%
GOOGLE_API_KEY = "AIzaSyCFCPqu6Ql9HW3PzORhkGcdsZcrRn5_Yuw"

# %%
import datasets
from utils import generate_prompts
import google.generativeai as palm
from evaluation import evaluate
import json
# Out:
# c:\Users\PARMESH YADAV\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
palm.configure(api_key=GOOGLE_API_KEY)

# %%
models = [m for m in palm.list_models() if 'generateText' in m.supported_generation_methods]
model = models[0].name
print(model)
# Out:
# models/text-bison-001

# %% [markdown]
# PROA - PRIVATE RIGHT OF ACTION

# %%
dataset_proa = datasets.load_dataset("nguha/legalbench", "proa")

# %%
dataset_proa["train"].to_pandas()
# Out:
#   answer index                                               text
# 0     No     0  Amendments to pleadings must be filed within 1...
# 1     No     1  A person who discloses genetic information in ...
# 2    Yes     2  A victim of human trafficking, as defined in S...
# 3    Yes     3  The lessees of any railroad or the company hav...
# 4    Yes     4  The buyer may recover from the seller as damag...

# %%
dataset_proa['test'].to_pandas()
# Out:
#    answer index                                               text
# 0     Yes     0  A buyer who has a claim against an escrow acco...
# 1     Yes     1  A cable operator may bring a civil action for ...
# 2     Yes     2  A consumer who suffers injury by an act of a c...
# 3     Yes     3  A custodian of a will who fails to comply with...
# 4     Yes     4  A customer described in subsection (1) who suf...
# ..    ...   ...                                                ...
# 90     No    90  Whenever it is necessary, in the judgment of t...
# 91     No    91  In the construction of a pleading, for the pur...
# 92     No    92  No application for parole shall be granted or ...
# 93     No    93  Not less than 123 days before a primary electi...
# 94     No    94  In connection with proceedings in the Supreme ...
#
# [95 rows x 3 columns]

# %% [markdown]
# FEW SHOT

# %%
with open(f"tasks/proa/base_prompt.txt") as in_file:
    prompt_template_proa = in_file.read()
print(prompt_template_proa)
# Out:
# A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?
#
# Clause: Amendments to pleadings must be filed within 15 days of the filing of the initial pleading.
# A: No
#
# Clause: A person who discloses genetic information in violation of this section is liable for a civil penalty of not more than $10,000. The attorney general may bring an action in the name of the state to recover the penalty, plus reasonable attorney's fees and court costs.
# A: No
#
# Clause: A victim of human trafficking, as defined in Section 236.1 of the Penal Code, may bring a civil action for actual damages, compensatory damages, punitive damages, injunctive relief, any combination of those, or any other appropriate relief.
# A: Yes
#
# ...

# %%
test_df = dataset_proa["test"].to_pandas()
prompts = generate_prompts(prompt_template=prompt_template_proa, data_df=test_df)
# print(len(prompts))
print(prompts[2])
# Out:
# A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?
#
# Clause: Amendments to pleadings must be filed within 15 days of the filing of the initial pleading.
# A: No
#
# Clause: A person who discloses genetic information in violation of this section is liable for a civil penalty of not more than $10,000. The attorney general may bring an action in the name of the state to recover the penalty, plus reasonable attorney's fees and court costs.
# A: No
#
# Clause: A victim of human trafficking, as defined in Section 236.1 of the Penal Code, may bring a civil action for actual damages, compensatory damages, punitive damages, injunctive relief, any combination of those, or any other appropriate relief.
# A: Yes
#
# ...

# %%
completion = palm.generate_text(
    model=model,
    prompt=f"""
You are a legal expert who only gives Yes/No answers.

{prompts[0]}
""",
    temperature=0,
    # The maximum length of the response
    max_output_tokens=1,
)

output = completion.result
print(output)
# Out:
# Yes

# %%
generations = []
for i, prompt in enumerate(prompts):
    print(f"Generating for prompt {i}")
    completion = palm.generate_text(
        model=model,
        prompt=f"""
        You are a legal expert who only gives Yes/No answers.

        {prompt}
        """,
        temperature=0,
        # The maximum length of the response
        max_output_tokens=1,
    )
    generations.append(completion.result)
# Out:
# Generating for prompt 0
# Generating for prompt 1
# Generating for prompt 2
# Generating for prompt 3
# Generating for prompt 4
# Generating for prompt 5
# Generating for prompt 6
# Generating for prompt 7
# Generating for prompt 8
# Generating for prompt 9
# Generating for prompt 10
# Generating for prompt 11
# Generating for prompt 12
# Generating for prompt 13
# Generating for prompt 14
# Generating for prompt 15
# Generating for prompt 16
# Generating for prompt 17
# Generating for prompt 18
# Generating for prompt 19
# Generating for prompt 20
# Generating for prompt 21
# Generating for prompt 22
# Generating for prompt 23
# Generating for prompt 24
# Generating for prompt 25
# Generating for prompt 26
# Generating for prompt 27
# Generating for prompt 28
# Generating for prompt 29
# Generating for prompt 30
# Generating for prompt 31
# Generating for prompt 32
# Generating for prompt 33
# Generating for prompt 34
# Generating for prompt 35
# Generating for prompt 36
# ...

# %%
print(generations)
# Out:
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No']

# %%
evaluate("proa", generations, test_df["answer"].tolist())
# Out:
# 0.9270833333333333

# %% [markdown]
# FEW SHOT COT

# %%
clauses = [
    'Amendments to pleadings must be filed within 15 days of the filing of the initial pleading.',
    'A person who discloses genetic information in violation of this section is liable for a civil penalty of not more than $10,000. The attorney general may bring an action in the name of the state to recover the penalty, plus reasonable attorneys fees and court costs.',
    'A victim of human trafficking, as defined in Section 236.1 of the Penal Code, may bring a civil action for actual damages, compensatory damages, punitive damages, injunctive relief, any combination of those, or any other appropriate relief.',
    'The lessees of any railroad or the company having possession of the railroad shall be liable to an action of any kind in the same court or jurisdiction as were the lessors or owners of the railroad before the lease.',
    'The buyer may recover from the seller as damages the difference between the cost of cover and the contract price together with any incidental or consequential damages.'
]
answers = ['No','No','Yes','Yes','Yes']

# %%
reasons = []
for i, question in enumerate(clauses):
    completion = palm.generate_text(
        model=model,
        prompt=f"""
        You are a legal expert.
        Clause:{clauses[i]}
        Answer:{answers[i]}
        A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute.
        Give reason for above Clause answer pair.
        Think Step by Step.
        """,
        temperature=0.3,
        max_output_tokens=1024,
    )
    print(completion.result)
    # output = json.loads(completion.result)['reason']
    reasons.append(completion.result)
# Out:
# The clause is about the time limit for filing amendments to pleadings. The answer is no because a private right of action is not related to the time limit for filing amendments to pleadings.
# The clause states that the attorney general may bring an action in the name of the state to recover the penalty. This means that the attorney general is the only person who can bring a lawsuit to enforce the statute. Therefore, there is no private right of action under this statute.
# None
# The clause states that the lessees of any railroad or the company having possession of the railroad shall be liable to an action of any kind in the same court or jurisdiction as were the lessors or owners of the railroad before the lease. This means that the lessees or company having possession of the railroad have a private right of action against the lessors or owners of the railroad before the lease.
# ...

# %%
#creating a new prompt template
prompt_template_temp = "A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?\n"
for i in range(len(clauses)):
    prompt_template_temp += f'''
Clause: {clauses[i]}
A: {answers[i]}
R: {reasons[i]}
'''
prompt_template_temp+='''
Q: {{text}}
A:
R:
'''
print(prompt_template_temp)
# Out:
# A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?
#
# Clause: Amendments to pleadings must be filed within 15 days of the filing of the initial pleading.
# A: No
# R: The clause is about the time limit for filing amendments to pleadings. The answer is no because a private right of action is not related to the time limit for filing amendments to pleadings.
#
# Clause: A person who discloses genetic information in violation of this section is liable for a civil penalty of not more than $10,000. The attorney general may bring an action in the name of the state to recover the penalty, plus reasonable attorneys fees and court costs.
# A: No
# ...

# %%
test_df = dataset_proa["test"].to_pandas()
prompts = generate_prompts(prompt_template=prompt_template_temp, data_df=test_df)
# print(len(prompts))
print(prompts[0])
# Out:
# A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?
#
# Clause: Amendments to pleadings must be filed within 15 days of the filing of the initial pleading.
# A: No
# R: The clause is about the time limit for filing amendments to pleadings. The answer is no because a private right of action is not related to the time limit for filing amendments to pleadings.
#
# Clause: A person who discloses genetic information in violation of this section is liable for a civil penalty of not more than $10,000. The attorney general may bring an action in the name of the state to recover the penalty, plus reasonable attorneys fees and court costs.
# A: No
# ...

# %%
completion = palm.generate_text(
    model=model,
    prompt=f"""
    You are a legal expert who only gives Yes/No answers with explaination in json format
    Statements:{prompts[0]}
    Output Format: JSON with keys answer and reason
    """,
    temperature=0.3,
    # The maximum length of the response
    max_output_tokens=1024,
)
print(completion.result)
output = json.loads(completion.result)['answer']
print(output)
# Out:
# {
#   "answer": "Yes",
#   "reason": "A buyer who has a claim against an escrow account required by may bring a civil action against the seller or escrow account holder to recover money from the escrow account. This is a private right of action because a regular person, a private citizen, is legally entitled to enforce their rights under the given statute."
# }
# Yes

# %%
generations = []
for i, prompt in enumerate(prompts):
    print(f"Generating for prompt {i}")
    completion = palm.generate_text(
        model=model,
        prompt=f"""
        You are a legal expert who only gives Yes/No answers with explanation in JSON format
        Statements:{prompt}
        Output Format: First word should be Yes/No
        """,
        temperature=0.3,
        # The maximum length of the response
        max_output_tokens=1024,
    )
    # output = completion.result.strip()  # Remove leading/trailing whitespaces
    # if output:
    #     output = json.loads(output)
    # else:
    #     output = {}
    # print(output)
    print(completion.result)
    #get the first word
    output = completion.result.split()[0]
    print(output)
    # output = output['answer']
    generations.append(output)
# Out:
# Generating for prompt 0
# Yes
# R: The buyer has a private right of action against the seller or escrow account holder to recover money from the escrow account.
# Yes
# Generating for prompt 1
# Yes
# R: None
# Yes
# Generating for prompt 2
# Yes
# R: The clause states that a consumer who suffers injury by an act of a consumer reporting agency that violates this chapter may bring a civil action against the consumer reporting agency in a circuit or superior court in the county in which the consumer resides. This is a private right of action because a regular person, a private citizen, is legally entitled to enforce their rights under the given statute.
# Yes
# Generating for prompt 3
# Yes
# ...

# %%
print(generations)
# Out:
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', '{', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'A:', 'Yes', 'A:', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'A:', 'A:', 'No', 'No', 'Yes', 'No', '{', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', '{', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'A:', 'No', 'No']

# %%
evaluate("proa", generations, test_df["answer"].tolist())
# Out:
# c:\Users\PARMESH YADAV\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 0.7914450354609929

# %% [markdown]
# ZERO SHOT

# %%
prompts = test_df["text"].tolist()
# print(prompts)

# %%
print(prompts[0])
# Out:
# A buyer who has a claim against an escrow account required by may bring a civil action against the seller or escrow account holder to recover money from the escrow account.

# %%
completion = palm.generate_text(
    model=model,
    prompt=f"""
    You are a legal expert who only gives Yes/No answers.
    A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?
    Clause:{prompts[0]}
    """,
    temperature=0,
    # The maximum length of the response
    max_output_tokens=1,
)

output = completion.result
print(output)
# Out:
# Yes

# %%
generations = []
for i, prompt in enumerate(prompts):
    print(f"Generating for prompt {i}")
    completion = palm.generate_text(
        model=model,
        prompt=f"""
        You are a legal expert who only gives Yes/No answers.
        A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action?
        Clause:{prompt}
        """,
        temperature=0,
        # The maximum length of the response
        max_output_tokens=1,
    )
    generations.append(completion.result)
# Out:
# Generating for prompt 0
# Generating for prompt 1
# Generating for prompt 2
# Generating for prompt 3
# Generating for prompt 4
# Generating for prompt 5
# Generating for prompt 6
# Generating for prompt 7
# Generating for prompt 8
# Generating for prompt 9
# Generating for prompt 10
# Generating for prompt 11
# Generating for prompt 12
# Generating for prompt 13
# Generating for prompt 14
# Generating for prompt 15
# Generating for prompt 16
# Generating for prompt 17
# Generating for prompt 18
# Generating for prompt 19
# Generating for prompt 20
# Generating for prompt 21
# Generating for prompt 22
# Generating for prompt 23
# Generating for prompt 24
# Generating for prompt 25
# Generating for prompt 26
# Generating for prompt 27
# Generating for prompt 28
# Generating for prompt 29
# Generating for prompt 30
# Generating for prompt 31
# Generating for prompt 32
# Generating for prompt 33
# Generating for prompt 34
# Generating for prompt 35
# Generating for prompt 36
# ...

# %%
print(generations)
# Out:
# ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', None, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No']

# %%
evaluate("proa", generations, test_df["answer"].tolist())
# Out:
# c:\Users\PARMESH YADAV\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:2394: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 0.9472517730496455

# %% [markdown]
# Zero Shot COT

# %%
completion = palm.generate_text(
    model=model,
    prompt=f"""
    You are a legal expert who only gives Yes/No answers with explaination in json format with keys as answer and reason.
    Clause:{prompts[0]}
    Output Format: json
    A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action? Think Step by Step
    """,
    temperature=0.3,
    # The maximum length of the response
    max_output_tokens=1024,
)
print(completion.result)
output = json.loads(completion.result)['answer']
print(output)
# Out:
# {
#      "answer": "Yes",
#      "reason": "A buyer who has a claim against an escrow account required by may bring a civil action against the seller or escrow account holder to recover money from the escrow account."
#     }
# Yes

# %%
generations = []
for i, prompt in enumerate(prompts):
    print(f"Generating for prompt {i}")
    completion = palm.generate_text(
        model=model,
        prompt=f"""
        You are a legal expert who only gives Yes/No answers with explaination in json format with keys as answer and reason.
        Statement:{prompt}
        Output Format: json
        A private right of action is when a regular person, a private citizen, is legally entitled to enforce their rights under a given statute. Does the clause specify a private right of action? Think Step by Step
        """,
        temperature=0.3,
        # The maximum length of the response
        max_output_tokens=1024,
    )
    print(completion.result)
    if(completion.result == None):
        output = "No"
    else:
        output = json.loads(completion.result)['answer']
    generations.append(output)
# Out:
# Generating for prompt 0
# {
#             "answer": "Yes",
#             "reason": "The clause states that a buyer who has a claim against an escrow account required by may bring a civil action against the seller or escrow account holder to recover money from the escrow account. This means that a regular person, a private citizen, is legally entitled to enforce their rights under the given statute."
#         }
# Generating for prompt 1
# {
#             "answer": "Yes",
#             "reason": "A cable operator is a private person, and the clause allows them to bring a civil action against anyone who violates a provision of ORS."
#         }
# Generating for prompt 2
# {
#   "answer": "Yes",
#   "reason": [
#     "A consumer who suffers injury by an act of a consumer reporting agency that violates this chapter may bring a civil action against the consumer reporting agency in a circuit or superior court in the county in which the consumer resides."
#   ]
# }
# ...

# %%
print(generations)
# Out:
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No']

# %%
evaluate("proa", generations, test_df["answer"].tolist()[:len(generations)])
# Out:
# 0.9368351063829787
